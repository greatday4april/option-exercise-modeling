# %%
from tax import get_fy_projection, Event, FYS, FMV_AT_EXERCISE
import pandas as pd

def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(False, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(False, FYS["2023"], events)
    ])
# Out:
# [{'year': '2022', 'cash': 1402932, 'status': 'married', 'family_income': 440083, 'capital_gain': 1135699, 'eff_tax_rate': 0.31, 'federal_income_tax': 109598, 'ca_income_tax': 10172, 'capital_gain_tax': 267220, 'federal_amt_tax': 79246, 'ca_amt_tax': 15594}, {'year': '2023', 'cash': 985066, 'status': 'married', 'family_income': 622906, 'capital_gain': 576799, 'eff_tax_rate': 0.26, 'federal_income_tax': 177351, 'ca_income_tax': 0, 'capital_gain_tax': 137278, 'federal_amt_tax': 0, 'ca_amt_tax': 0}, {'year': '2024', 'cash': 489206, 'status': 'married', 'family_income': 693204, 'capital_gain': 0, 'eff_tax_rate': 0.29, 'federal_income_tax': 203997, 'ca_income_tax': 0, 'capital_gain_tax': 0, 'federal_amt_tax': 0, 'ca_amt_tax': 0}, {'year': '2025', 'cash': 4024857, 'status': 'married', 'family_income': 6833073, 'capital_gain': 0, 'eff_tax_rate': 0.41, 'federal_income_tax': 2620035, 'ca_income_tax': 188180, 'capital_gain_tax': 0, 'federal_amt_tax': 0, 'ca_amt_tax': 0}]
# /Users/james/.pyenv/versions/3.7.7/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Financial Planning

# %% [markdown]
# ### Trading Windows
#
# 1. Feb 15 ~ Mar 15
# 2. May 15 ~ Jun 15
# 3. Aug 15 ~ Sep 15
# 4. Nov 15 ~ Dec 15

# %%
events = [
    Event("Jun 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022","sale", "nso", 5375 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Dec 01 2022","sale", "nso", 10250 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022  1410771  married         440083       1139443          0.31
# 1  2022  1448409   single         440083       1139443          0.28
# 2  2023   985066  married         622906        576799          0.26
# 3  2023   981130   single         622906        576799          0.27
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109598          10172            268111            79246
# 1              121460          10567            263111            34747
# 2              177351              0            137278                0
# 3              185115              0            133450                0
#
#    ca_amt_tax
# 0       15594
# 1       15200
# 2           0
# 3           0

# %% [markdown]
# ### TO take advantage of higher stock price, spread out some NSO sale to 2023

# %%
events = [
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   775037  married         440083        580047          0.34
# 1  2022   812675   single         440083        580047          0.31
# 2  2023  1733749  married         622906       1290968          0.25
# 3  2023  1729813   single         622906       1290968          0.26
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109598          10172            134975            79246
# 1              121460          10567            129975            34747
# 2              177351              0            307250                0
# 3              185115              0            303422                0
#
#    ca_amt_tax
# 0       15594
# 1       15200
# 2           0
# 3           0

# %%
def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(True, FYS["2024"], events),
    ])

# %% [markdown]
# ### Move ISO exercise and some NSO exericse to 2023 to minimize AMT

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023", "exercise", "iso", 6377),
    
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "sale", "iso", 6377,Event("Mar 01 2023", "exercise", "iso", 6377).price),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   969870  married         440083        580047          0.25
# 1  2023  1508441  married        1365491        714168          0.32
# 2  2024  2478257  married        3169174        618569          0.37
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109598          10172            134975                0
# 1              468542          27847            169972             2719
# 2             1178291          83965            147219                0
#
#    ca_amt_tax
# 0           0
# 1        6632
# 2           0

# %% [markdown]
# ### Move ISO exercise to 2024 to minimize CA AMT tax

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   969870  married         440083        580047          0.25
# 1  2023  1617784  married        1365491        714168          0.32
# 2  2024  1806926  married        3169174             0          0.40
# 3  2025  2460339  married        2898184        786347          0.36
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109598          10172            134975                0
# 1              468542          27847            169972                0
# 2             1178291          83965                 0                0
# 3             1071656          65375            187150                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0

# %% [markdown]
# ### Move early exercised NSO sales to later years assuming stock price is higher in future
#
# *But this has risk in the event of long term capital gain got canceled*

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","exercise and sale", "nso", 4000),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4500),
    Event("Jun 01 2023","exercise and sale", "nso", 5000),
    
    Event("Sep 01 2023","exercise and sale", "nso", 5000),
    Event("Dec 01 2023","exercise and sale", "nso", 5500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 6000),
    Event("Jun 01 2024","exercise and sale", "nso", 6500),

    Event("Sep 01 2024","sale", "nso", 7687 , FMV_AT_EXERCISE),
    Event("Dec 01 2024","sale", "nso", 7688 , FMV_AT_EXERCISE),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 13623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   778552  married         696643        273213          0.30
# 1  2023  1354537  married        2243966             0          0.40
# 2  2024  2694669  married        1948864       1680106          0.31
# 3  2025  2105549  married        2281634        786347          0.35
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              205350          23172             65024                0
# 1              814221          75205                 0                0
# 2              698099          43076            399865                0
# 3              829044          46228            187150                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0

# %% [markdown]
# ### After tweak

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4000),
    Event("Jun 01 2023","exercise and sale", "nso", 4500),
    
    Event("Sep 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
  
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]
pd.DataFrame([e.json() for e in events])
# Out:
#    option_type  quantity       date   price           txn_type  \
# 0          nso      5125 2022-09-01   73.26               sale
# 1          nso      5125 2022-12-01   79.82               sale
# 2          nso      4000 2023-03-01   86.31  exercise and sale
# 3          nso      4500 2023-06-01   92.94  exercise and sale
# 4          nso      5125 2023-09-01   99.57               sale
# 5          nso      5125 2023-12-01  106.13               sale
# 6          iso      6377 2024-03-01  112.68           exercise
# 7          nso      5000 2024-03-01  112.68  exercise and sale
# 8          nso      5500 2024-06-01  119.32  exercise and sale
# 9          nso      6000 2024-09-01  125.95  exercise and sale
# 10         nso      6500 2024-12-01  132.50  exercise and sale
# 11         iso      6377 2025-03-01  138.99               sale
# 12         nso     18623 2025-03-01  138.99  exercise and sale
#
#     exercise_price     cash    cost
# 0            19.95   375457       0
# 1            19.95   409077       0
# 2              NaN   345240   62720
# 3              NaN   418230   70560
# 4            19.95   510296       0
# 5            19.95   543916       0
# 6              NaN        0   99991
# 7              NaN   563400   78400
# 8              NaN   656260   86240
# 9              NaN   755700   94080
# 10             NaN   861250  101920
# 11          112.68   886339       0
# 12             NaN  2588410  292008

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   969870  married         440083        580047          0.25
# 1  2023  1652198  married        1253096        849724          0.31
# 2  2024  1806926  married        3169174             0          0.40
# 3  2025  2460339  married        2898184        786347          0.36
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109598          10172            134975                0
# 1              424314          28559            202234                0
# 2             1178291          83965                 0                0
# 3             1071656          65375            187150                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0
