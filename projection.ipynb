# %%
from tax import get_fy_projection, Event, FYS, FMV_AT_EXERCISE
import pandas as pd

def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(False, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(False, FYS["2023"], events)
    ])

# %% [markdown]
# ## Financial Planning

# %% [markdown]
# ### Trading Windows
#
# 1. Feb 15 ~ Mar 15
# 2. May 15 ~ Jun 15
# 3. Aug 15 ~ Sep 15
# 4. Nov 15 ~ Dec 15

# %%
events = [
    Event("Jun 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022","sale", "nso", 5375 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Dec 01 2022","sale", "nso", 10250 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year    cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022  976922  married         440464        485788          0.28
# 1  2022  995015   single         440464        485788          0.26
# 2  2023  728585  married         563943        288686          0.26
# 3  2023  725146   single         563943        288686          0.27
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109729          10174            112560            24227
# 1              121159          10540            107265                0
# 2              155329              0             68707                0
# 3              163548              0             63926                0
#
#    ca_amt_tax
# 0        6608
# 1        6242
# 2           0
# 3           0

# %% [markdown]
# ### TO take advantage of higher stock price, spread out some NSO sale to 2023

# %%
events = [
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   587500  married         440464        249638          0.30
# 1  2022   605594   single         440464        249638          0.27
# 2  2023  1180781  married         563943        613765          0.26
# 3  2023  1177343   single         563943        613765          0.26
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109729          10174             56357            24227
# 1              121159          10540             51061                0
# 2              155329              0            146076                0
# 3              163548              0            141294                0
#
#    ca_amt_tax
# 0        6608
# 1        6242
# 2           0
# 3           0

# %%
def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(True, FYS["2024"], events),
    ])

# %% [markdown]
# ### Move ISO exercise and some NSO exericse to 2023 to minimize AMT

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023", "exercise", "iso", 6377),
    
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "sale", "iso", 6377,Event("Mar 01 2023", "exercise", "iso", 6377).price),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   718328  married         440464        249638          0.26
# 1  2023   970496  married         933978        325078          0.31
# 2  2024  1516302  married        1894861        312217          0.36
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109729          10174             56357                0
# 1              298742          12494             77368                0
# 2              676849          39610             74307                0
#
#    ca_amt_tax
# 0           0
# 1        4450
# 2           0

# %% [markdown]
# ### Move ISO exercise to 2024 to minimize CA AMT tax

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   718328  married         440464        249638          0.26
# 1  2023  1074938  married         933978        325078          0.31
# 2  2024  1078410  married        1894861             0          0.38
# 3  2025  1513771  married        1758147        406533          0.35
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109729          10174             56357                0
# 1              298742          12494             77368                0
# 2              676849          39610                 0                0
# 3              623052          31093             96755                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0

# %% [markdown]
# ### Move early exercised NSO sales to later years assuming stock price is higher in future
#
# *But this has risk in the event of long term capital gain got canceled*

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","exercise and sale", "nso", 4000),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4500),
    Event("Jun 01 2023","exercise and sale", "nso", 5000),
    
    Event("Sep 01 2023","exercise and sale", "nso", 5000),
    Event("Dec 01 2023","exercise and sale", "nso", 5500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 6000),
    Event("Jun 01 2024","exercise and sale", "nso", 6500),

    Event("Sep 01 2024","sale", "nso", 7687 , FMV_AT_EXERCISE),
    Event("Dec 01 2024","sale", "nso", 7688 , FMV_AT_EXERCISE),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 13623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   581612  married         562344        115363          0.29
# 1  2023   862727  married        1363618             0          0.37
# 2  2024  1655903  married        1267391        830021          0.31
# 3  2025  1329911  married        1439397        406533          0.33
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              154732          16150             27456                0
# 1              467805          33086                 0                0
# 2              429939          19529            197545                0
# 3              497624          21631             96755                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2        1233
# 3           0

# %% [markdown]
# ### After tweak

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4000),
    Event("Jun 01 2023","exercise and sale", "nso", 4500),
    
    Event("Sep 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
  
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]
pd.DataFrame([e.json() for e in events])
# Out:
#    option_type  quantity       date  price           txn_type  exercise_price  \
# 0          nso      5125 2022-09-01  42.46               sale           19.95
# 1          nso      5125 2022-12-01  46.15               sale           19.95
# 2          nso      4000 2023-03-01  49.80  exercise and sale             NaN
# 3          nso      4500 2023-06-01  53.53  exercise and sale             NaN
# 4          nso      5125 2023-09-01  57.26               sale           19.95
# 5          nso      5125 2023-12-01  60.95               sale           19.95
# 6          iso      6377 2024-03-01  64.64           exercise             NaN
# 7          nso      5000 2024-03-01  64.64  exercise and sale             NaN
# 8          nso      5500 2024-06-01  68.36  exercise and sale             NaN
# 9          nso      6000 2024-09-01  72.09  exercise and sale             NaN
# 10         nso      6500 2024-12-01  75.78  exercise and sale             NaN
# 11         iso      6377 2025-03-01  79.43               sale           64.64
# 12         nso     18623 2025-03-01  79.43  exercise and sale             NaN
#
#        cash    cost
# 0    217607       0
# 1    236518       0
# 2    199200   62720
# 3    240885   70560
# 4    293457       0
# 5    312368       0
# 6         0   99991
# 7    323200   78400
# 8    375980   86240
# 9    432540   94080
# 10   492570  101920
# 11   506525       0
# 12  1479224  292008

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   718328  married         440464        249638          0.26
# 1  2023  1094547  married         870748        401338          0.30
# 2  2024  1078410  married        1894861             0          0.38
# 3  2025  1513771  married        1758147        406533          0.35
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              109729          10174             56357                0
# 1              273861          12646             95518                0
# 2              676849          39610                 0                0
# 3              623052          31093             96755                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0
