# %%
from tax import get_fy_projection, Event, FYS, FMV_AT_EXERCISE
import pandas as pd

def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(False, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(False, FYS["2023"], events)
    ])

# %% [markdown]
# ## Financial Planning

# %% [markdown]
# ### Trading Windows
#
# 1. Feb 15 ~ Mar 15
# 2. May 15 ~ Jun 15
# 3. Aug 15 ~ Sep 15
# 4. Nov 15 ~ Dec 15

# %%
events = [
    Event("Jun 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022","sale", "nso", 5375 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Dec 01 2022","sale", "nso", 10250 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022  1365514  married         450002       1062305          0.30
# 1  2022  1403152   single         450002       1062305          0.28
# 2  2023   934582  married         631832        503209          0.26
# 3  2023   930199   single         631832        503209          0.27
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              113006          10211            250248            72706
# 1              125165          10613            245248            27909
# 2              180685              0            119763                0
# 3              188449              0            116382                0
#
#    ca_amt_tax
# 0       14590
# 1       14189
# 2           0
# 3           0

# %% [markdown]
# ### TO take advantage of higher stock price, spread out some NSO sale to 2023

# %%
events = [
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   756262  married         450002        537663          0.34
# 1  2022   793900   single         450002        537663          0.30
# 2  2023  1625390  married         631832       1141425          0.26
# 3  2023  1621007   single         631832       1141425          0.26
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              113006          10211            125384            72706
# 1              125165          10613            120384            27909
# 2              180685              0            271659                0
# 3              188449              0            268277                0
#
#    ca_amt_tax
# 0       14590
# 1       14189
# 2           0
# 3           0

# %%
def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(True, FYS["2024"], events),
    ])

# %% [markdown]
# ### Move ISO exercise and some NSO exericse to 2023 to minimize AMT

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023", "exercise", "iso", 6377),
    
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "sale", "iso", 6377,Event("Mar 01 2023", "exercise", "iso", 6377).price),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   943550  married         450002        537663          0.25
# 1  2023  1406651  married        1282927        638216          0.32
# 2  2024  2212136  married        2813965        534583          0.37
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              113006          10211            125384                0
# 1              436053          23944            151895              341
# 2             1038516          70656            127230                0
#
#    ca_amt_tax
# 0           0
# 1        6752
# 2           0

# %% [markdown]
# ### Move ISO exercise to 2024 to minimize CA AMT tax

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   943550  married         450002        537663          0.25
# 1  2023  1513736  married        1282927        638216          0.32
# 2  2024  1604801  married        2813965             0          0.39
# 3  2025  2158138  married        2539305        660402          0.36
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              113006          10211            125384                0
# 1              436053          23944            151895                0
# 2             1038516          70656                 0                0
# 3              930438          53946            157175                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0

# %% [markdown]
# ### Move early exercised NSO sales to later years assuming stock price is higher in future
#
# *But this has risk in the event of long term capital gain got canceled*

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","exercise and sale", "nso", 4000),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4500),
    Event("Jun 01 2023","exercise and sale", "nso", 5000),
    
    Event("Sep 01 2023","exercise and sale", "nso", 5000),
    Event("Dec 01 2023","exercise and sale", "nso", 5500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 6000),
    Event("Jun 01 2024","exercise and sale", "nso", 6500),

    Event("Sep 01 2024","sale", "nso", 7687 , FMV_AT_EXERCISE),
    Event("Dec 01 2024","sale", "nso", 7688 , FMV_AT_EXERCISE),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 13623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   760620  married         686722        256250          0.30
# 1  2023  1257861  married        2069162             0          0.39
# 2  2024  2397639  married        1782375       1414041          0.31
# 3  2025  1860025  married        2021505        660402          0.34
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              201446          22160             60987                0
# 1              745436          65863                 0                0
# 2              632585          36388            336541                0
# 3              726683          38013            157175                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0

# %% [markdown]
# ### After tweak

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4000),
    Event("Jun 01 2023","exercise and sale", "nso", 4500),
    
    Event("Sep 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
  
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]
pd.DataFrame([e.json() for e in events])
# Out:
#    option_type  quantity       date   price           txn_type  \
# 0          nso      5125 2022-09-01   69.95               sale
# 1          nso      5125 2022-12-01   74.86               sale
# 2          nso      4000 2023-03-01   79.73  exercise and sale
# 3          nso      4500 2023-06-01   84.70  exercise and sale
# 4          nso      5125 2023-09-01   89.68               sale
# 5          nso      5125 2023-12-01   94.59               sale
# 6          iso      6377 2024-03-01   99.51           exercise
# 7          nso      5000 2024-03-01   99.51  exercise and sale
# 8          nso      5500 2024-06-01  104.49  exercise and sale
# 9          nso      6000 2024-09-01  109.46  exercise and sale
# 10         nso      6500 2024-12-01  114.38  exercise and sale
# 11         iso      6377 2025-03-01  119.24               sale
# 12         nso     18623 2025-03-01  119.24  exercise and sale
#
#     exercise_price     cash    cost
# 0            19.95   358493       0
# 1            19.95   383657       0
# 2              NaN   318920   62720
# 3              NaN   381150   70560
# 4            19.95   459610       0
# 5            19.95   484773       0
# 6              NaN        0   99991
# 7              NaN   497550   78400
# 8              NaN   574695   86240
# 9              NaN   656760   94080
# 10             NaN   743470  101920
# 11           99.51   760393       0
# 12             NaN  2220606  292008

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   943550  married         450002        537663          0.25
# 1  2023  1538611  married        1198622        739896          0.31
# 2  2024  1604801  married        2813965             0          0.39
# 3  2025  2158138  married        2539305        660402          0.36
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              113006          10211            125384                0
# 1              402879          25418            176095                0
# 2             1038516          70656                 0                0
# 3              930438          53946            157175                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2           0
# 3           0
