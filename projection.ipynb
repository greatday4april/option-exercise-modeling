# %%
from tax import get_fy_projection, Event, FYS, FMV_AT_EXERCISE
import pandas as pd

def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(False, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(False, FYS["2023"], events)
    ])

# %% [markdown]
# ## Financial Planning

# %% [markdown]
# ### Trading Windows
#
# 1. Feb 15 ~ Mar 15
# 2. May 15 ~ Jun 15
# 3. Aug 15 ~ Sep 15
# 4. Nov 15 ~ Dec 15

# %%
events = [
    Event("Jun 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022","sale", "nso", 5375 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Dec 01 2022","sale", "nso", 10250 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022  1451679  married         459510       1172705          0.30
# 1  2022  1492439   single         459510       1172705          0.28
# 2  2023   989099  married         622906        582092          0.26
# 3  2023   985162   single         622906        582092          0.27
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              116323           5059            276999            80890
# 1              127850           8003            271526            34075
# 2              177351              0            138538                0
# 3              185115              0            134710                0
#
#    ca_amt_tax
# 0       15233
# 1       12289
# 2           0
# 3           0

# %% [markdown]
# ### TO take advantage of higher stock price, spread out some NSO sale to 2023

# %%
events = [
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Sep 01 2022", "exercise", "iso", 6377),
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023", "sale", "iso", 6377, Event("Sep 01 2022", "exercise", "iso", 6377).price)
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   802783  married         459510        596037          0.34
# 1  2022   843542   single         459510        596037          0.30
# 2  2023  1747428  married         622906       1308920          0.25
# 3  2023  1743491   single         622906       1308920          0.26
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              116323           5059            139752            80890
# 1              127850           8003            134279            34075
# 2              177351              0            311522                0
# 3              185115              0            307695                0
#
#    ca_amt_tax
# 0       15233
# 1       12289
# 2           0
# 3           0

# %%
def projections(events):
    return pd.DataFrame([
        get_fy_projection(True, FYS["2022"], events),
        get_fy_projection(True, FYS["2023"], events),
        get_fy_projection(True, FYS["2024"], events),
    ])

# %% [markdown]
# ### Move ISO exercise and some NSO exericse to 2023 to minimize AMT

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023", "exercise", "iso", 6377),
    
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "sale", "iso", 6377,Event("Mar 01 2023", "exercise", "iso", 6377).price),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),
]
projections(events)
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   998751  married         459510        596037          0.25
# 1  2023  1527873  married        1373186        726827          0.32
# 2  2024  2516772  married        3178599        622905          0.36
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              116323           5059            139752                0
# 1              471570          17592            172984             4203
# 2             1182000          54470            148251                0
#
#    ca_amt_tax
# 0         146
# 1       10284
# 2           0

# %% [markdown]
# ### Move ISO exercise to 2024 to minimize CA AMT tax

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Jun 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    Event("Sep 01 2023","exercise and sale", "nso", 4000),
    Event("Dec 01 2023","exercise and sale", "nso", 4500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   998751  married         459510        596037          0.25
# 1  2023  1642352  married        1373186        726827          0.32
# 2  2024  1842137  married        3178599             0          0.39
# 3  2025  2484971  married        2898742        786539          0.35
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              116323           5059            139752                0
# 1              471570          17592            172984                0
# 2             1182000          54470                 0                0
# 3             1071876          41228            187196                0
#
#    ca_amt_tax
# 0         146
# 1           0
# 2           0
# 3           0

# %% [markdown]
# ### Move early exercised NSO sales to later years assuming stock price is higher in future
#
# *But this has risk in the event of long term capital gain got canceled*

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","exercise and sale", "nso", 4000),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4500),
    Event("Jun 01 2023","exercise and sale", "nso", 5000),
    
    Event("Sep 01 2023","exercise and sale", "nso", 5000),
    Event("Dec 01 2023","exercise and sale", "nso", 5500),
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 6000),
    Event("Jun 01 2024","exercise and sale", "nso", 6500),

    Event("Sep 01 2024","sale", "nso", 7687 , FMV_AT_EXERCISE),
    Event("Dec 01 2024","sale", "nso", 7688 , FMV_AT_EXERCISE),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 13623),
]

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   805976  married         721990        281618          0.30
# 1  2023  1391500  married        2265171             0          0.39
# 2  2024  2711891  married        1956194       1684180          0.31
# 3  2025  2123622  married        2282042        786539          0.34
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              215324          17525             67025                0
# 1              822566          51103                 0                0
# 2              700983          27297            400835                0
# 3              829205          28549            187196                0
#
#    ca_amt_tax
# 0           0
# 1           0
# 2        6106
# 3           0

# %% [markdown]
# ### After tweak

# %%
events = [
    # 2022
    Event("Sep 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2022","sale", "nso", 5125 , FMV_AT_EXERCISE),
    
    # 2023
    Event("Mar 01 2023","exercise and sale", "nso", 4000),
    Event("Jun 01 2023","exercise and sale", "nso", 4500),
    
    Event("Sep 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
    Event("Dec 01 2023","sale", "nso", 5125 , FMV_AT_EXERCISE),
  
    
    # 2024
    Event("Mar 01 2024", "exercise", "iso", 6377),
    
    Event("Mar 01 2024","exercise and sale", "nso", 5000),
    Event("Jun 01 2024","exercise and sale", "nso", 5500),
    Event("Sep 01 2024","exercise and sale", "nso", 6000),
    Event("Dec 01 2024","exercise and sale", "nso", 6500),

    # 2025
    Event("Mar 01 2025", "sale", "iso", 6377, Event("Mar 01 2024", "exercise", "iso", 6377).price),
    Event("Mar 01 2025","exercise and sale", "nso", 18623),
]
pd.DataFrame([e.json() for e in events])
# Out:
#    option_type  quantity       date   price           txn_type  \
# 0          nso      5125 2022-09-01   74.90               sale
# 1          nso      5125 2022-12-01   81.30               sale
# 2          nso      4000 2023-03-01   87.63  exercise and sale
# 3          nso      4500 2023-06-01   94.09  exercise and sale
# 4          nso      5125 2023-09-01  100.56               sale
# 5          nso      5125 2023-12-01  106.96               sale
# 6          iso      6377 2024-03-01  113.36           exercise
# 7          nso      5000 2024-03-01  113.36  exercise and sale
# 8          nso      5500 2024-06-01  119.82  exercise and sale
# 9          nso      6000 2024-09-01  126.29  exercise and sale
# 10         nso      6500 2024-12-01  132.69  exercise and sale
# 11         iso      6377 2025-03-01  139.02               sale
# 12         nso     18623 2025-03-01  139.02  exercise and sale
#
#     exercise_price     cash    cost
# 0            19.95   383862       0
# 1            19.95   416662       0
# 2              NaN   350520   62720
# 3              NaN   423405   70560
# 4            19.95   515370       0
# 5            19.95   548170       0
# 6              NaN        0   99991
# 7              NaN   566800   78400
# 8              NaN   659010   86240
# 9              NaN   757740   94080
# 10             NaN   862485  101920
# 11          113.36   886530       0
# 12             NaN  2588969  292008

# %%
pd.DataFrame([
      get_fy_projection(True, FYS["2022"], events),
      get_fy_projection(True, FYS["2023"], events),
      get_fy_projection(True, FYS["2024"], events),
      get_fy_projection(True, FYS["2025"], events),
  ])
# Out:
#    year     cash   status  family_income  capital_gain  eff_tax_rate  \
# 0  2022   998751  married         459510        596037          0.25
# 1  2023  1675191  married        1263551        859052          0.31
# 2  2024  1842137  married        3178599             0          0.39
# 3  2025  2484971  married        2898742        786539          0.35
#
#    federal_income_tax  ca_income_tax  capital_gain_tax  federal_amt_tax  \
# 0              116323           5059            139752                0
# 1              428428          19016            204454                0
# 2             1182000          54470                 0                0
# 3             1071876          41228            187196                0
#
#    ca_amt_tax
# 0         146
# 1           0
# 2           0
# 3           0
